# %% [markdown]
# ### Atividade Acadêmica da matéria Testes e Implementação de Software.
# #### Nesta Atividade desenvolvi um teste manual da tela de cadastro, para testar cada botão e funcionalidades.
# #### Com cenário ilustrativo de como testar as entradas por tipo de variável aceita em cada campo de preenchimento, e demais botões como: Excluir, Confirmar, Cancelar e Fechar a aba de cadastro.
# #### Irei abrir o arquivo que desenvolvi os teste que está em formato xlsx dentro da IDE para não ser necessário baixar o arquivo, pois dentrodo meu GitHub não aparece a tabela.

# %%
import pandas as pd

template_testes = pd.read_excel('Template MAPA Teste e Implementacao de Software.xlsx')
template_testes = template_testes.drop([0,1,2,3,4], axis = 0)
display(template_testes)
# Out:
#    ROTEIRO DE TESTES Unnamed: 1         Unnamed: 2  \
# 5     ETAPA DO TESTE  CATEGORIA     FUNCIONALIDADE
# 6                 T1    Entrada  Campo CPF ou CNPJ
# 7                 T2    Entrada  Campo CPF ou CNPJ
# 8                 T3    Entrada     Buscar Cliente
# 9                 T4    Entrada     Buscar Cliente
# 10                T5    Entrada    Nome do Cliente
# 11                T6    Entrada    Nome do Cliente
# 12                T7    Entrada   Data do Cadastro
# 13                T8    Entrada   Data do Cadastro
# 14                T9    Entrada                Rua
# 15               T10    Entrada                Rua
# 16               T11    Entrada      Número da Rua
# 17               T12    Entrada      Número da Rua
# 18               T13    Entrada             Bairro
# 19               T14    Entrada             Bairro
# 20               T15    Entrada        Complemento
# 21               T16    Entrada        Complemento
# ...
